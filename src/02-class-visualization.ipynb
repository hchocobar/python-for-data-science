# %% [markdown]
# # Visualización de Datos

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
from fontTools.varLib.avar import plan

# %% [markdown]
# ## 1. Gráfico de línea simple
#
# - Importamos librerías con alias
# - Generamos dos ejes:
#     - x con 20 números entre 1 a 50
#     - y con el logaritmo de x
# - Genero un gráfico de línea

# %%
x = [ 1.        ,  3.57894737,  6.15789474,  8.73684211, 11.31578947,
     13.89473684, 16.47368421, 19.05263158, 21.63157895, 24.21052632,
     26.78947368, 29.36842105, 31.94736842, 34.52631579, 37.10526316,
     39.68421053, 42.26315789, 44.84210526, 47.42105263, 50.        ]
y = [0.        , 1.27506873, 1.81773496, 2.16754881, 2.42619905,
     2.63151012, 2.80176421, 2.94720523, 3.07415424, 3.18678751,
     3.28800904, 3.37991998, 3.46408981, 3.54172181, 3.61375882,
     3.68095339, 3.74391573, 3.80314755, 3.85906628, 3.91202301]

# %%
plt.plot(x, y, color='r', linestyle='-', linewidth=2, marker='o')
plt.xlabel('eje x')
plt.ylabel('eje y')
plt.title('Gráfico de Linea')
# plt.grid(True)
plt.legend(['Linea roja'])

plt.show()

# %% [markdown]
# ## 1.2 Gráfico de líneas

# %%
x = [1, 2 , 3, 4]
y = [5, 10, 15, 20]
z = [4, 11, 16, 12 ]

plt.plot(x, y, color='y', marker='o')
plt.plot(x, z, color='r', marker='+')
plt.legend(['Linea azul', 'Linea roja'])
plt.title('Grafico de dos tendencias')
plt.xlabel('eje x')
plt.ylabel('eje y')
plt.show()

# %% [markdown]
# ## 2. Gráfico de dispersión
#
# - Generamos dos ejes:
#     - x: 50 números entre el 1 al 100 con numpy
#     - y: 50 números entre el 1 al 100 con numpy
#     - generamos el gráfico de dispersión

# %%
x = [41,  6, 17, 53, 65, 20, 50, 30,  1, 52,
     85, 66, 76, 73, 85, 82,  7, 19, 16,  2,
     41, 18, 71, 75, 34, 47, 24, 29, 16, 96,
     34, 91, 87, 87, 69,  5, 67, 61, 82, 97,
     93, 50, 64, 92, 27, 26, 32, 12, 69, 94]
y = [88, 39, 97, 57,  2, 98, 93, 60, 68, 94,
     10, 56, 82, 93, 35,  3, 19, 72, 32, 62,
     58, 88, 55, 58, 49, 16, 14,  1, 32, 49,
     45, 51, 30, 19, 75, 46, 47, 89, 69, 86,
     18, 13, 16, 22, 20, 17, 39, 60, 97, 35]

# %%
plt.scatter(x, y, color='r', marker='o')
plt.xlabel('eje x')
plt.ylabel('eje y')
plt.title('Gráfico de Dispersión')
plt.grid(True)
plt.legend(['Puntos rojos'])

plt.show()

# %% [markdown]
# ## 3. Histograma
#
# - Generamos datos según la distribución normal
# - Generamos un histograma
#   - atención con los 'bins'
#   - https://numpy.org/doc/stable/reference/generated/numpy.histogram_bin_edges.html#numpy.histogram_bin_edges

# %%
data = [-1.59475799,  0.99015914,  2.51477118, -0.79857194,  1.32501303,
       -1.96472405,  1.42846101,  1.44081689, -0.28966596,  0.15724276,
       -1.47515246,  0.33693093, -1.16436534,  1.82991194,  0.4470656 ,
        0.13316937, -1.16882741,  0.38382619, -0.76810864, -0.0251508 ,
        2.38799845, -1.01001068, -0.05241844, -0.18502845, -0.20095194,
       -0.19597305, -0.01061759,  1.11161449, -0.51033942,  0.49934277,
       -1.14382845, -0.28713451, -0.66469542, -0.94189982,  0.29570261,
       -0.05786782,  0.77246232,  0.70242822, -0.25160921, -1.42528391,
        1.25897071, -0.03970317,  0.26606613,  1.00486959, -1.53493683,
        1.28018757, -0.0494706 ,  1.17051772, -0.3557249 ,  0.71726855,
        0.290861  ,  1.77463451, -1.01961333,  0.11525164, -1.69898275,
        0.26976158, -1.6120163 , -0.07711645, -0.95690572,  0.93356583,
        0.44990871,  0.14434543,  0.27453373, -0.98530933, -0.25916598,
        0.37865209, -0.74779209, -0.51767396, -0.27005641, -1.77652837,
       -0.814671  , -0.85217497,  0.01057984, -1.43787536, -0.2042146 ,
        0.89004467, -0.97839653, -1.92472697,  1.17277028, -1.03487196,
        1.5781767 , -0.13021871,  0.8284294 ,  0.10636741,  1.67106348,
       -0.8231429 , -1.14462206, -0.16409143, -0.20671672, -0.61482331,
        0.52648887, -0.10852034,  0.61513508, -0.92727905, -0.52749876,
        1.25023406,  0.55192851, -0.23000861, -0.08311195, -1.07563689]

# %%
plt.hist(data, bins='auto', color='r', edgecolor='black')
plt.xlabel('eje x: valores')
plt.ylabel('eje y: frecuencia')
plt.title('Histograma de datos')

plt.show()

# %% [markdown]
# ## 4. Gráficos de barras

# %%
categories = ['Albo', 'Bar', 'Color']
values = [20, 42, 10]

# %%
plt.bar(categories, values, color='r')
plt.title('Gráfico de barras')
plt.xticks(categories, rotation=45)
plt.ylabel('Valor')
plt.legend('Categorías')
plt.show()

# %% [markdown]
# ## 5. Pie chart
#
# - Definimos 4 labels
# - Generamos sizes: 4 números enteros aleatorios entre 1 y 100

# %%
labels = ['A', 'B', 'C', 'D']

# %%
sizes = np.random.randint(1, 100, 4)
sizes
# Out:
# array([46, 49, 62, 22])

# %%
plt.pie(sizes, labels=labels, autopct='%1.0f%%')
plt.title('Grafico de torta')


plt.show()

# %% [markdown]
# ## 6. Gráficos a partir de un dataset
#
# - Cargamos el dataset 'titanic' desde seaborn

# %%
df = sns.load_dataset('titanic')
# sns.get_dataset_names()

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# - Indicar a matplotlib que queremos crear una figura con 4 gráficos (2x2)
#     1. Gráfico de línea: edad vs. tarifa promedio (age, fare)
#     2. Gráfico de barras para la tasa de supervivencia en función de la clase (pclass, survived)
#     3. Gráfico de dispersión edad vs. tarifa
#     4. Gráfico de pastel Supervivientes vs. No supervivientes (survieved)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
age_fare = df.groupby(['age'])['fare'].mean()
survival_class = df.groupby(['pclass'])['survived'].mean()
survived_counts = df['survived'].value_counts()

# %%
survived_counts
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# Definimos los subplots
fig, ax = plt.subplots(2, 2, figsize=(13, 8))

# Primer gráfico
ax[0, 0].plot(age_fare.index, age_fare.values)
ax[0, 0].set_title('Edad vs tarifa promedio')
ax[0, 0].set_xlabel('Edad')
ax[0, 0].set_ylabel('Tarifa promedio')

# 2do
ax[0, 1].bar(survival_class.index,
             survival_class.values,
             tick_label=['1ra clase', '2da clase', '3ra clase'])
ax[0, 1].set_title('Supervivencia por Clase')
ax[0, 1].set_xlabel('Clase')
ax[0, 1].set_ylabel('Proporción de Supervivencia')

# Subplot 3: Gráfico de dispersión edad vs. tarifa
ax[1, 0].scatter(df['age'], df['fare'])
ax[1, 0].set_title('Edad vs. Tarifa')
ax[1, 0].set_xlabel('Edad')
ax[1, 0].set_ylabel('Tarifa')

# Subplot 4: Gráfico pastel Supervivientes vs. No supervivientes
ax[1, 1].pie(survived_counts,
            labels=['No sobrevivientes', 'Sobrevivientes'],
            autopct=lambda x: f'{x:1.2f} %')  # autopct=lambda pct: f'{pct:1.1f} %'  con formato viejo: '%1.1f%%'

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Gráfico 3D
#
# - Generar datos sintéticos con 3 grupos (coordenadas x, y, z y el grupo al cual pertenecen)
#   - Que hay en coordenadas
#   - Que hay en grupos
# - Creamos un DataFrame con las coordenadas y los grupos

# %%
# coordenadas, grupo = make_blobs(n_samples=1000, centers=3, n_features=3, random_state=42)

# %%
tips = sns.load_dataset("tips")
sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
fig.show()
