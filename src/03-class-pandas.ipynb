# %% [markdown]
# # Pandas
#
# Ejemplos de captación de un dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/hchocobar/ds-datasets/blob/main/data/raw/AB_NYC_2019.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('https://github.com/hchocobar/ds-datasets/blob/main/data/raw/AB_NYC_2019.csv')
#
# File /media/hector/hdd-hch/code/python-for-data-science/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %%
url = "https://raw.githubusercontent.com/hchocobar/ds-datasets/main/data/raw/financiero-producto.csv"

df = pd.read_csv(url)
df.head()
# Out:
#                             Product ProductID Familia CategoriaPrecio  \
# Amarilla  PRD006 Mountain   Premium     '$260     00'           '$350
# Carretera PRD001 Road         Entry       '$3     00'            '$20
# Montana   PRD002 Road         Entry       '$5     00'            '$20
# Paseo     PRD003 Urban     Standard      '$10     00'            '$20
# Velo      PRD004 Touring    Premium     '$120     00'           '$125
#
#                           Manufacturing Price Std PrecioListaReferencia  \
# Amarilla  PRD006 Mountain                     00'                   '25
# Carretera PRD001 Road                         00'                   '85
# Montana   PRD002 Road                         00'                   '75
# Paseo     PRD003 Urban                        00'                   '50
# Velo      PRD004 Touring                      00'                    '4
#
#                           MargenTeoricoPct EstadoProducto
# ...

# %%
file_csv = '../data/raw/Localidades.csv'
df = pd.read_csv(file_csv)
df
# Out:
#      A  AA       CANELONES
# 0    A  AO         JOANICO
# 1    A  BA     SANTA LUCIA
# 2    A  BO         EMPALME
# 3    A  CA       CERRILLOS
# 4    A  CO  AGUAS CORRIENT
# ..  ..  ..             ...
# 451  R  AW    PASO D.CERRO
# 452  R  AX           IPORA
# 453  R  AY       CARAGUATA
# 454  R  AZ     PIEDRA SOLA
# 455  V  AA      MONTEVIDEO
#
# [456 rows x 3 columns]
